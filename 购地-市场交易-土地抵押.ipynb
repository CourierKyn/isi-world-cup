# %%
import pandas as pd
data=pd.read_excel("赛题1数据材料\赛题1数据集\购地-市场交易-土地抵押.xlsx" ,index_col="企业编号")
data
# Out:
#       土地抵押人性质  抵押面积(公顷)        土地用途      抵押土地用途 抵押土地权属性质与使用权类型       土地面积  \
# 企业编号
# 1001      NaN       NaN      商务金融用地         NaN            NaN   0.018960
# 1001      NaN       NaN      商务金融用地         NaN            NaN   0.012060
# 1001      NaN       NaN      商务金融用地         NaN            NaN   0.049570
# 1001      NaN       NaN      商务金融用地         NaN            NaN   0.762853
# 1001      NaN       NaN      商务金融用地         NaN            NaN   0.762853
# 1001      NaN       NaN      其他商服用地         NaN            NaN   0.764940
# 1001      NaN       NaN      商务金融用地         NaN            NaN   8.065610
# 1001     有限公司   10.8261        工业用地        工业用地           国有出让  10.826100
# 1001     有限公司    3.2054        工业用地        工业用地           国有出让   3.205400
# 1001       企业    6.5283        住宅用地        住宅用地             国有   6.528300
# 1001      NaN    3.8533  其他普通商品住房用地  其他普通商品住房用地            出让地   3.853300
# 1001      股份制    3.7990      工矿仓储用地      工矿仓储用地             出让   3.799000
# ...

# %%
df=data.iloc[:,[2,6,7]]
df
# Out:
#             土地用途     评估金额(万元)   抵押金额(万元)
# 企业编号
# 1001      商务金融用地          NaN        NaN
# 1001      商务金融用地          NaN        NaN
# 1001      商务金融用地          NaN        NaN
# 1001      商务金融用地          NaN        NaN
# 1001      商务金融用地          NaN        NaN
# 1001      其他商服用地          NaN        NaN
# 1001      商务金融用地          NaN        NaN
# 1001        工业用地    2921.0000   1200.000
# 1001        工业用地     847.6500    400.000
# 1001        住宅用地    9990.9100   4995.455
# 1001  其他普通商品住房用地   19386.0000   2516.000
# 1001      工矿仓储用地   11049.0000   8850.000
# 1001        工业用地     858.6100    429.350
# 1001        工业用地    2871.0000   1000.000
# 1001        工业用地    3172.0000   1500.000
# 1001        住宅用地     282.0000    160.000
# 1001        住宅用地     744.0000    410.000
# 1001      商务金融用地    1945.0000   1080.000
# 1001        商服用地    2075.0000   1150.000
# 1001        工业用地     587.0400    400.000
# 1001          05  260498.6500  90000.000
# 1001      工矿仓储用地     476.0100    230.000
# ...
