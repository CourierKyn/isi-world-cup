# %%
from IPython.display import display
import pandas as pd
import csv
import random
import re
# import pyperclip
import numpy as np
import seaborn as sns
import requests
import matplotlib, matplotlib.pyplot as plt
import pprint
import os
import dateutil
import datetime
data=pd.read_excel("赛题1数据材料\赛题1数据集\年报-股东（发起人）及出资信息.xlsx").drop_duplicates(keep='first'
                                                                         ).set_index(["企业编号","年报年份"])
data.columns=['股东类型', '股东所占比例', '$认缴出资信息', '实缴出资信息']

# %%
def get_number(cell):
    if not isinstance(cell, str):
        return cell
    _ = re.findall(r'[\d.]+',cell)
    if not _:
        return None
    return float(_[0])

# %%
df=data[["$认缴出资信息"]].applymap(get_number)

# %%
result=df.groupby(["企业编号","年报年份"]).sum().unstack().T
result
# Out:
# 企业编号                    1001       1002      1003         1004         1005  \
#         年报年份
# $认缴出资信息 2013.0  3.945927e+06  115000.00  120200.0   80728.2534  220000.0000
#         2014.0  3.945927e+06  115000.00  120200.0   80728.2534  220000.0000
#         2015.0  3.945927e+06  115000.00  120200.0  100728.2534  241030.7062
#         2016.0  5.552004e+06  115000.00  120200.0  100728.2534  241030.7062
#         2017.0  2.232209e+06  206932.05  120200.0  100728.2534  482061.4124
#         2018.0           NaN        NaN       NaN          NaN          NaN
#
# 企业编号                   1006          1007          1008      1009      1010  \
#         年报年份
# $认缴出资信息 2013.0  192695.8448  8.002591e+05  7.214130e+05  165861.0  307584.0
#         2014.0  192695.8448  1.600518e+06  7.210130e+05  165861.0  307584.0
#         2015.0  192695.8448  3.256074e+06  7.216363e+05  165861.0  398804.0
#         2016.0  192695.8448  3.256074e+06  7.232481e+05  165861.0  387858.0
# ...

# %%
result=result.reindex(columns=list(range(1001,4001)))
result.to_pickle('年报-股东（发起人）及出资信息.pickle')
