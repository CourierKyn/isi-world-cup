# %%
import pandas as pd

data=pd.read_excel("赛题1数据材料\赛题1数据集\商标.xlsx")
data
# Out:
#         企业编号         商标状态        申请日期  专用权期限开始日期   专用权期限结束日期  \
# 0       1001         评审分案  2015-12-28        NaN         NaN
# 1       1001           注册  2016-07-28        NaN         NaN
# 2       1001       商标变更完成  2005-07-25        NaN  2019-02-27
# 3       1001       商标变更完成  2007-01-18        NaN  2020-05-13
# 4       1001        商标已注册  2012-06-11        NaN  2023-12-06
# 5       1001     等待驳回通知发文  2017-12-25        NaN         NaN
# 6       1001         商标无效  2005-09-19        NaN         NaN
# 7       1001       等待实质审查  2016-03-16        NaN         NaN
# 8       1001         商标无效  2015-07-21        NaN         NaN
# 9       1001           注册  2015-12-28        NaN  2027-02-06
# 10      1001           注册  2016-05-10        NaN  2027-06-27
# 11      1001           注册  2016-03-16        NaN  2027-04-20
# 12      1001           注册  2014-12-25        NaN  2026-02-27
# 13      1001           注册  2015-05-11        NaN  2026-07-06
# ...

# %%
data["商标状态"].value_counts()#状态过多，忽略
# Out:
# 商标已注册                          45235
# 等待受理通知书发文                      38770
# 注册                             35809
# 商标无效                           30956
# 商标注册申请完成                       22107
# 商标续展完成                         20149
# 商标变更完成                         17424
# 核准证明打印发送                       15039
# 等待实质审查                         13399
# 初步审定公告                         10896
# 变更商标申请人/注册人名义/地址完成              9772
# 等待受理通知发文                        8724
# 申请收文                            7338
# 商标注册申请注册公告排版完成                  7004
# 商标转让完成                          5855
# 等待注册公告公示期                       5652
# 等待驳回通知发文                        5280
# 出具商标注册证明完成                      4992
# 商标注册申请等待受理中                     3387
# 商标转让中                           3267
# 等待打印受理通知书                       2009
# 商标续展中                           1954
# 变更商标申请人/注册人名义/地址中               1860
# 开具注册证明完成                        1760
# 排版注册公告                          1756
# ...
