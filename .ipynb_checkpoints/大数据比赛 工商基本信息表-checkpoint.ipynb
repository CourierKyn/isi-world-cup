# %%
import pandas as pd
data=pd.read_excel(r"C:\Users\Administrator\.ipynb_checkpoints\工商基本信息表.xlsx", index_col="企业编号").T
data
# Out:
# 企业编号                1001        1002          1003        1004        1005  \
# 注册资本（万元）         746.139     82.7728            80     40.2913     227.418
# 注册资本币种(正则)           人民币         人民币           人民币         人民币         人民币
# 成立日期          1992-10-19  2000-09-19    1999-07-21  1997-10-15  1999-08-31
# 经营状态        存续（在营、开业、在册）    在营（开业）企业  存续（在营、开业、在册）          开业          开业
# 行业大类（代码）               J           O             C           F           L
# 行业小类（代码）              66          80            36          52          72
# 类型                    民营          民营            民营          民营          民营
# 省份代码                  31          44            42          11          11
# 城市代码                3100        4400          4200        1101        1101
# 地区代码              310000      440000        420000      110105      110102
# 是否上市                   Y           Y             Y           Y           Y
# ...

# %% [markdown]
# ## 筛选数据

# %%
df=data.iloc[[0,5,6,7,10,15],:]
df
# Out:
# 企业编号         1001     1002 1003     1004     1005     1006    1007     1008  \
# 注册资本（万元）  746.139  82.7728   80  40.2913  227.418  77.0783  1823.4  608.015
# 行业小类（代码）       66       80   36       52       72       56      25       44
# 类型             民营       民营   民营       民营       民营       民营      民营       外企
# 省份代码           31       44   42       11       11       31      15       11
# 是否上市            Y        Y    Y        Y        Y        Y       Y        Y
# 员工人数           19       12   11       15       15       14      63       22
#
# 企业编号         1009     1010   ...       3991     3992     3993     3994  3995  \
# 注册资本（万元）  66.3444  512.907   ...    21.9802  18.1007  19.0682  17.2022  23.4
# 行业小类（代码）       54       66   ...         72       39       27       39    51
# 类型             外企       民营   ...         民营       民营       民营       民营    民营
# 省份代码           34       11   ...         21       33       11       42    44
# ...

# %%
dummy_leixin=pd.get_dummies(df.iloc[2][:])
dummy_shangshi=pd.get_dummies(df.iloc[4][:])
result=df.append(dummy_leixin.T).append(dummy_shangshi.T)
result_2=result.drop(index=["类型","是否上市","外企","N"])
result_2
# Out:
# 企业编号         1001     1002 1003     1004     1005     1006    1007     1008  \
# 注册资本（万元）  746.139  82.7728   80  40.2913  227.418  77.0783  1823.4  608.015
# 行业小类（代码）       66       80   36       52       72       56      25       44
# 省份代码           31       44   42       11       11       31      15       11
# 员工人数           19       12   11       15       15       14      63       22
# 民营              1        1    1        1        1        1       1        0
# Y               1        1    1        1        1        1       1        1
#
# 企业编号         1009     1010   ...       3991     3992     3993     3994  3995  \
# 注册资本（万元）  66.3444  512.907   ...    21.9802  18.1007  19.0682  17.2022  23.4
# 行业小类（代码）       54       66   ...         72       39       27       39    51
# 省份代码           34       11   ...         21       33       11       42    44
# 员工人数           12       29   ...         13       10       13       12    11
# ...
